# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
data = pd.read_excel('faa_wildlife_strikes.xlsx')

# %%
data.head()
# Out:
#   Airport: Code               Airport: Name  Origin State Origin State Code  \
# 0          KAAF  APALACHICOLA REGIONAL ARPT       Florida                FL
# 1          KAAF  APALACHICOLA REGIONAL ARPT       Florida                FL
# 2          KABE          LEHIGH VALLEY INTL  Pennsylvania                PA
# 3          KABE          LEHIGH VALLEY INTL  Pennsylvania                PA
# 4          KABE          LEHIGH VALLEY INTL  Pennsylvania                PA
#
#          Country Aircraft: Type  Aircraft: Number of engines  \
# 0  United States            NaN                          NaN
# 1  United States       Airplane                          1.0
# 2  United States       Airplane                          2.0
# 3  United States       Airplane                          2.0
# 4  United States       Airplane                          2.0
#
#   Collision Date and Time When: Time of day When: Phase of flight  ...  \
# 0     2012-09-20 19:30:00               NaN          Take-off run  ...
# 1     2013-04-23 17:09:00               NaN          Take-off run  ...
# 2     2009-04-23 09:22:00               Day          Take-off run  ...
# 3     2014-04-13 22:00:00             Night              Approach  ...
# 4     2009-03-31 18:15:00               Day              Approach  ...
#
#      Days Feet above ground Miles from airport  Wildlife: Animal Category  \
# 0     NaN               0.0                NaN        Terrestrial Mammals
# 1     NaN               NaN                NaN                      Birds
# 2  30.000               0.0                0.0                      Birds
# 3   0.625               NaN                NaN                      Birds
# 4   0.500               NaN                0.0                      Birds
#
#                       Wildlife: Species Order      Wildlife: Species Group  \
# 0                                      Canids  Wolves, Dogs, Foxes, Coyote
# 1  Pelicans, Herons, Egrets, Bitterns, Ibises     Herons, Egrets, Bitterns
# 2                          Caracaras, Falcons           Caracaras, Falcons
# 3                           Pigeons and Doves                        Doves
# 4     Hawks, Kites, Eagles, Ospreys, Vultures         Kites, Hawks, Eagles
#
#           Wildlife: Species  Wildlife: Species ID Number of Strikes Record ID
# 0              Domestic dog                  1F12                 1     17459
# 1  Herons, egrets, bitterns                    I1                 1     17114
# 2          American kestrel                 K5114                 1    259361
# 3             Mourning dove                 O2205                 1    345167
# 4           Red-tailed hawk                 K3302                 1    262782
#
# [5 rows x 25 columns]

# %%
data.shape
# Out:
# (28298, 25)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28298 entries, 0 to 28297
# Data columns (total 25 columns):
# Airport: Code                                 28298 non-null object
# Airport: Name                                 28298 non-null object
# Origin State                                  28298 non-null object
# Origin State Code                             28298 non-null object
# Country                                       28298 non-null object
# Aircraft: Type                                27467 non-null object
# Aircraft: Number of engines                   25918 non-null float64
# Collision Date and Time                       28298 non-null datetime64[ns]
# When: Time of day                             27655 non-null object
# When: Phase of flight                         27892 non-null object
# Effect: Amount of damage (detailed)           28298 non-null object
# Effect: Impact to flight                      28084 non-null object
# Effect: Indicated Damage                      28298 non-null object
# Cost: Aircraft time out of service (hours)    2929 non-null float64
# Cost: Total $                                 28298 non-null int64
# Days                                          2929 non-null float64
# Feet above ground                             24872 non-null float64
# Miles from airport                            19807 non-null float64
# Wildlife: Animal Category                     28298 non-null object
# Wildlife: Species Order                       28298 non-null object
# Wildlife: Species Group                       28298 non-null object
# Wildlife: Species                             28298 non-null object
# Wildlife: Species ID                          28298 non-null object
# Number of Strikes                             28298 non-null int64
# Record ID                                     28298 non-null int64
# dtypes: datetime64[ns](1), float64(5), int64(3), object(16)
# memory usage: 5.4+ MB

# %%
data.isna().sum()
# Out:
# Airport: Code                                     0
# Airport: Name                                     0
# Origin State                                      0
# Origin State Code                                 0
# Country                                           0
# Aircraft: Type                                  831
# Aircraft: Number of engines                    2380
# Collision Date and Time                           0
# When: Time of day                               643
# When: Phase of flight                           406
# Effect: Amount of damage (detailed)               0
# Effect: Impact to flight                        214
# Effect: Indicated Damage                          0
# Cost: Aircraft time out of service (hours)    25369
# Cost: Total $                                     0
# Days                                          25369
# Feet above ground                              3426
# Miles from airport                             8491
# Wildlife: Animal Category                         0
# Wildlife: Species Order                           0
# Wildlife: Species Group                           0
# Wildlife: Species                                 0
# Wildlife: Species ID                              0
# Number of Strikes                                 0
# Record ID                                         0
# dtype: int64

# %%
msno.matrix(data)

# %% [markdown]
# Drop columns with lots of missing values, two columns: 'Cost: Aircraft time out of service (hours)', 'Days'

# %%
data2 = data.drop(columns = ['Cost: Aircraft time out of service (hours)', 'Days'])

# %%
data2.shape
# Out:
# (28298, 23)

# %% [markdown]
# count rows with missing values

# %%
# data2.isnull().sum(axis=1)

# %%
msno.matrix(data2)

# %%
data2.to_csv('strikes_clean.csv')
